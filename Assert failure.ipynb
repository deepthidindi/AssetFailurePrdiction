# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df=pd.read_csv('project.csv')

# %%
df.corr()
# Out:
#              Temperature  Humidity  Measure1  Measure2  Measure3  Measure4  \
# Temperature     1.000000 -0.045661  0.000796  0.002787 -0.007428 -0.015234
# Humidity       -0.045661  1.000000 -0.000619 -0.011132 -0.007573  0.004571
# Measure1        0.000796 -0.000619  1.000000 -0.013846 -0.008231  0.002793
# Measure2        0.002787 -0.011132 -0.013846  1.000000 -0.027071  0.002475
# Measure3       -0.007428 -0.007573 -0.008231 -0.027071  1.000000 -0.012008
# Measure4       -0.015234  0.004571  0.002793  0.002475 -0.012008  1.000000
# Measure5        0.007868 -0.029283  0.013409  0.000496 -0.000126 -0.000696
#
#              Measure5
# Temperature  0.007868
# Humidity    -0.029283
# Measure1     0.013409
# Measure2     0.000496
# Measure3    -0.000126
# Measure4    -0.000696
# Measure5     1.000000

# %%
sns.pairplot(df,hue='Failure')

# %%
sns.heatmap(df.corr(),cmap='coolwarm')

# %%
df
# Out:
#       Temperature  Humidity  Measure1  Measure2  Measure3  Measure4  Measure5  \
# 0              67        82       291         1         1      1041       846
# 1              68        77      1180         1         1      1915      1194
# 2              64        76      1406         1         1       511      1577
# 3              63        80       550         1         1      1754      1834
# 4              65        81      1928         1         2      1326      1082
# 5              67        84       398         1         2      1901      1801
# 6              67        83       847         0         2      1849      1141
# 7              67        76      1021         2         1       185       170
# 8              65        80      1731         2         0      1424      1176
# 9              63        80       415         0         0      1008      1086
# 10             61        83       525         2         2       603      1630
# 11             62        81      1719         3         1       880       575
# 12             62        76      1116         0         0       588       166
# 13             60        82       282         1         1      1406      1727
# 14             61        79       637         3         0       821       511
# 15             64        77      1831         0         2      1277      1622
# 16             60        80      1622         3         2       846      1462
# 17             64        85      1885         3         2       503       569
# 18             62        82       616         2         2       634      1722
# 19             60        75       965         2         0       176      1456
# 20             60        82      1238         2         1       171      1595
# 21             67        78      1327         0         1      1248      1185
# 22             63        79       632         1         2      1037       543
# 23             66        85       861         3         1      1962      1391
# 24             67        75       298         2         2       678       211
# 25             67        82       333         0         2      1407      1305
# 26             69        82      1196         2         1       343       471
# 27             61        84      1909         1         2      1102      1846
# 28             63        79      1645         0         1       311      1314
# 29             63        84      1004         3         2      1760       372
# ...           ...       ...       ...       ...       ...       ...       ...
# 8754           61        82      1835         0         0      1936      1508
# 8755           60        75      1527         0         2      1412       860
# 8756           65        78       835         3         0       573      1182
# 8757           67        83      1638         3         0       334       517
# 8758           66        80       158         2         2       331      1636
# 8759           65        79       226         0         0       276       643
# 8760           64        78      1212         0         0       849       212
# 8761           63        79       498         3         2      1967      1659
# 8762           65        79       494         0         2      1940      1364
# 8763           66        85      1422         0         2      1824       515
# 8764           62        75      1403         3         1      1100       726
# 8765           66        80       737         2         0       712       162
# 8766           64        80      1018         1         1      1657      1264
# 8767           61        81       548         1         0       852      1403
# 8768           67        85      1706         3         0       300       679
# 8769           61        75       837         1         1      1433      1999
# 8770           65        80      1801         2         1       964      1234
# 8771           77        69       869         0         1      1492      1779
# 8772           72        69       839         2         0      1253      1825
# 8773           66        79       868         1         0      1472      1329
# 8774           65        75      1006         2         1      1843      1715
# 8775           68        82      1541         1         2       991       488
# 8776           67        77       187         0         0      1389       624
# 8777           60        80       221         1         0      1374       920
# 8778           61        82      1613         2         0       918      1710
# 8779           66        79       937         0         2      1875      1719
# 8780           60        77       379         3         0       814      1990
# 8781           61        77       595         3         1      1659      1134
# 8782           72        81      1038         3         2       254      1400
# 8783           60        82       399         0         1       324      1424
#
#      Failure
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
# 5         No
# 6         No
# 7         No
# 8         No
# 9         No
# 10        No
# 11        No
# 12        No
# 13        No
# 14        No
# 15        No
# 16        No
# 17        No
# 18        No
# 19        No
# 20        No
# 21        No
# 22        No
# 23        No
# 24        No
# 25        No
# 26        No
# 27        No
# 28        No
# 29        No
# ...      ...
# 8754      No
# 8755      No
# 8756      No
# 8757      No
# 8758      No
# 8759      No
# 8760      No
# 8761      No
# 8762      No
# 8763      No
# 8764      No
# 8765      No
# 8766      No
# 8767      No
# 8768      No
# 8769      No
# 8770      No
# 8771     Yes
# 8772     Yes
# 8773      No
# 8774      No
# 8775      No
# 8776      No
# 8777      No
# 8778      No
# 8779      No
# 8780      No
# 8781      No
# 8782      No
# 8783      No
#
# [8784 rows x 8 columns]

# %%
x=df.iloc[:,0:7].values

# %%
x
# Out:
# array([[  67,   82,  291, ...,    1, 1041,  846],
#        [  68,   77, 1180, ...,    1, 1915, 1194],
#        [  64,   76, 1406, ...,    1,  511, 1577],
#        ...,
#        [  61,   77,  595, ...,    1, 1659, 1134],
#        [  72,   81, 1038, ...,    2,  254, 1400],
#        [  60,   82,  399, ...,    1,  324, 1424]], dtype=int64)

# %%
y=df.iloc[:,7].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
# Logistics Regression

# %%
from sklearn.linear_model.logistic import LogisticRegression
lr1=LogisticRegression()
lr1.fit(x_train,y_train)
lrpred=lr1.predict(x_test)
print(confusion_matrix(y_test,lrpred))
print(classification_report(y_test,lrpred))
print('accuracy',accuracy_score(y_test,lrpred))
# Out:
# [[2879    0]
#  [   9   11]]
#               precision    recall  f1-score   support
#
#           No       1.00      1.00      1.00      2879
#          Yes       1.00      0.55      0.71        20
#
#    micro avg       1.00      1.00      1.00      2899
#    macro avg       1.00      0.78      0.85      2899
# weighted avg       1.00      1.00      1.00      2899
#
# accuracy 0.9968954812004139
# E:\anaconda56\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
